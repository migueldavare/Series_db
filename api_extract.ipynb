# %%
from src.libraries.extract import (
    generate_month_dates_as_strings,
    fetch_data_to_dataframe,
    save_df_to_json_in_dir)
import pandas as pd
import os

# %%
init_month='2024-01'
list_days=generate_month_dates_as_strings(init_month) 
final_df=pd.DataFrame()
for date in list_days:
    url=f'http://api.tvmaze.com/schedule/web?date={date}'
    print(f'Extracting from URL : {url}')
    df=fetch_data_to_dataframe(url,method='GET')
    print(f'DF Extracted with {len(df)} rows')
    final_df = pd.concat([df, final_df])
final_df
# Out:
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-01
# DF Extracted with 265 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-02
# DF Extracted with 144 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-03
# DF Extracted with 113 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-04
# DF Extracted with 180 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-05
# DF Extracted with 163 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-06
# DF Extracted with 71 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-07
# DF Extracted with 71 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-08
# DF Extracted with 210 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-09
# DF Extracted with 140 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-10
# DF Extracted with 168 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-11
# DF Extracted with 233 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-12
# DF Extracted with 173 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-13
# DF Extracted with 73 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-14
# DF Extracted with 81 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-15
# DF Extracted with 162 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-16
# DF Extracted with 122 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-17
# DF Extracted with 173 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-18
# DF Extracted with 223 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-19
# DF Extracted with 276 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-20
# DF Extracted with 94 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-21
# DF Extracted with 112 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-22
# DF Extracted with 202 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-23
# DF Extracted with 137 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-24
# DF Extracted with 182 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-25
# DF Extracted with 222 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-26
# DF Extracted with 308 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-27
# DF Extracted with 95 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-28
# DF Extracted with 92 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-29
# DF Extracted with 169 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-30
# DF Extracted with 163 rows
# Extracting from URL : http://api.tvmaze.com/schedule/web?date=2024-01-31
# DF Extracted with 174 rows
#           id                                                url  \
# 0    2759405  https://www.tvmaze.com/episodes/2759405/a-seba...
# 1    2743334  https://www.tvmaze.com/episodes/2743334/frendz...
# 2    2760318  https://www.tvmaze.com/episodes/2760318/frendz...
# 3    2760319  https://www.tvmaze.com/episodes/2760319/frendz...
# 4    2693705  https://www.tvmaze.com/episodes/2693705/offlaj...
# ..       ...                                                ...
# 260  2833026  https://www.tvmaze.com/episodes/2833026/abc-pr...
# 261  2657625  https://www.tvmaze.com/episodes/2657625/wwe-mo...
# 262  2731565  https://www.tvmaze.com/episodes/2731565/maine-...
# 263  2732336  https://www.tvmaze.com/episodes/2732336/alle-e...
# 264  3045036  https://www.tvmaze.com/episodes/3045036/making...
#
#                                                  name  season  number  \
# 0                                    Игорь Джабраилов       5     1.0
# 1                                             Серия 1       2     1.0
# 2                                             Серия 2       2     2.0
# 3                                             Серия 3       2     3.0
# 4                                             Серия 9       2     9.0
# ..                                                ...     ...     ...
# 260                                         Episode 1    2024     1.0
# 261  #1597 - Day One: Pechanga Arena in San Diego, CA      31     1.0
# 262                         A Twofer in West Gardiner       9     7.0
# 263                            Stor, lykkelig familie       5     1.0
# 264                                  Derrick Todd Lee       2     1.0
#
#         type     airdate airtime                   airstamp  runtime  \
# 0    regular  2024-01-31          2024-01-31T00:00:00+00:00     86.0
# 1    regular  2024-01-31          2024-01-31T00:00:00+00:00     26.0
# 2    regular  2024-01-31          2024-01-31T00:00:00+00:00     23.0
# 3    regular  2024-01-31          2024-01-31T00:00:00+00:00     25.0
# 4    regular  2024-01-31          2024-01-31T00:00:00+00:00      NaN
# ..       ...         ...     ...                        ...      ...
# 260  regular  2024-01-01   19:00  2024-01-02T00:00:00+00:00     90.0
# 261  regular  2024-01-01   20:00  2024-01-02T01:00:00+00:00    180.0
# 262  regular  2024-01-01   21:00  2024-01-02T02:00:00+00:00     60.0
# 263  regular  2024-01-01   03:00  2024-01-02T02:00:00+00:00     20.0
# 264  regular  2024-01-01   00:00  2024-01-02T05:00:00+00:00     43.0
#
#                 rating                                              image  \
# 0    {'average': None}  {'medium': 'https://static.tvmaze.com/uploads/...
# 1    {'average': None}                                               None
# 2    {'average': None}                                               None
# 3    {'average': None}                                               None
# 4    {'average': None}                                               None
# ..                 ...                                                ...
# 260  {'average': None}                                               None
# 261     {'average': 9}  {'medium': 'https://static.tvmaze.com/uploads/...
# 262  {'average': None}  {'medium': 'https://static.tvmaze.com/uploads/...
# 263  {'average': None}                                               None
# 264  {'average': None}  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                                summary  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 260                                               None
# 261  <p>The People's Champion made his earth-shatte...
# 262  <p>The Maine Cabin Masters update a pair of ca...
# 263  <p>David and Andrea will organize Norway's big...
# 264  <p>Derrick Todd Lee, known as the Baton Rouge ...
#
#                                                 _links  \
# 0    {'self': {'href': 'https://api.tvmaze.com/epis...
# 1    {'self': {'href': 'https://api.tvmaze.com/epis...
# 2    {'self': {'href': 'https://api.tvmaze.com/epis...
# 3    {'self': {'href': 'https://api.tvmaze.com/epis...
# 4    {'self': {'href': 'https://api.tvmaze.com/epis...
# ..                                                 ...
# 260  {'self': {'href': 'https://api.tvmaze.com/epis...
# 261  {'self': {'href': 'https://api.tvmaze.com/epis...
# 262  {'self': {'href': 'https://api.tvmaze.com/epis...
# 263  {'self': {'href': 'https://api.tvmaze.com/epis...
# 264  {'self': {'href': 'https://api.tvmaze.com/epis...
#
#                                              _embedded
# 0    {'show': {'id': 47865, 'url': 'https://www.tvm...
# 1    {'show': {'id': 59613, 'url': 'https://www.tvm...
# 2    {'show': {'id': 59613, 'url': 'https://www.tvm...
# 3    {'show': {'id': 59613, 'url': 'https://www.tvm...
# 4    {'show': {'id': 61191, 'url': 'https://www.tvm...
# ..                                                 ...
# 260  {'show': {'id': 76215, 'url': 'https://www.tvm...
# 261  {'show': {'id': 802, 'url': 'https://www.tvmaz...
# 262  {'show': {'id': 23972, 'url': 'https://www.tvm...
# 263  {'show': {'id': 54476, 'url': 'https://www.tvm...
# 264  {'show': {'id': 69960, 'url': 'https://www.tvm...
#
# [4991 rows x 15 columns]

# %%
final_df = final_df.reset_index(drop=True)
final_df.to_csv('output_raw_data.csv')

# %%
directory_name = 'src/json_output/'
json_file_name = 'output_raw_data.json'

save_df_to_json_in_dir(final_df, json_file_name, directory_name)
# Out:
# DataFrame successfully saved to: src/json_output/output_raw_data.json
